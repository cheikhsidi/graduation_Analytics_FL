# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#%matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns

# %%
# list of US States
df_list =[]
states = ["AL","AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA",
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]
#state = "FL"

# list of parameters to pass to the URL
data = [r"acceptance-rate", r"tuition", r"graduation-rate", r"sat-act-scores", r"student-population"]

#lopping through state and parameters to fetch the data
for state in states:
    for dt in data:
        #contructing the URL
        url = f"https://www.collegetuitioncompare.com/compare/tables/?state={state}&factor={dt}"
        #scrapping the url using pandas
        response = pd.read_html(url)
        df_list.append(response)

len(df_list)
# Out:
# 255

# %%
# Extracting Dataframes into lists
Acceptance = []
Tuition = []
Graduation = []
SAT_ACT = []
Students_pop = []

#looping through the liast of the dataframes
for i in range (0,255,5):
    Acceptance.append(df_list[i][0])
    Tuition.append(df_list[i+1][0])
    Graduation.append(df_list[i+2][0])
    SAT_ACT.append(df_list[i+3][0])
    Students_pop.append(df_list[i+4][0])
    
#Adding State Column to each dataframe
for i in range(len(states)):
    Acceptance[i]["State"] = states[i]
    Tuition[i]["State"] = states[i]
    Graduation[i]["State"] = states[i]
    SAT_ACT[i]["State"] = states[i]
    Students_pop[i]["State"] = states[i]

# %%
# Conctinating Dataframes from my lists
Acceptance_df = pd.concat(Acceptance)
Tuition_df =  pd.concat(Tuition)
Graduation_df = pd.concat(Graduation)
SAT_ACT_df = pd.concat(SAT_ACT)
Students_pop_df = pd.concat(Students_pop)

# %%
# Exporting my dataframes to csv files
Acceptance_df.to_csv("data/Acceptance.csv")
Tuition_df.to_csv("data/Tuition.csv")
Graduation_df.to_csv("data/Graduation.csv")
SAT_ACT_df.to_csv("data/SAT_ACT.csv")
Students_pop_df.to_csv("data/Students_pop.csv")

# %%
#Target Universities
Target_Univ = ["Florida International University  Miami, FL", "Florida State University  Tallahassee, FL",
               "University of Central Florida  Orlando, FL",
               "University of Florida  Gainesville, FL",
               "University of South Florida-Main Campus  Tampa, FL"]

# %%
# Creating Formatting Function
def Top_Univ(df):
    df = df.loc[df['State'] == "FL"]
    df = df.loc[df['School Name'].str.replace(" ", "").isin([x.replace(" ", "") for x in Target_Univ])]
    df.insert (0, "School Abrev", ["FIU", "FSU", "UCF", "UF", "USF"])
    df.index = [0,1,2,3,4]
    c1 = df.columns[-1]
    column_arrang = df.columns.insert(0, c1)
    df = df[column_arrang]
    df = df.loc[:,~df.columns.duplicated()]
    return df

# %%
# Creating a function that generate scatter plot
def Plot(p1, p2):
    fig, ax = plt.subplots(figsize=(7,5))
    # Scatter Plot of Data using Seaborn
    lb = ["FIU", "FSU", "UCF", "UF", "USF"]
    plt.scatter(p1, p2, alpha=0.5)
    sns.regplot(p1, p2, color = "r")
    for i, txt in enumerate(lb):
        ax.annotate(txt, (p1[i], p2[i]), fontsize = 14, color ="b")
    plt.title(f"{p1.name} vs {p2.name}")
    #plt.legend()
    fig.savefig(f'{p1.name}_{p2.name}.png', dpi=100)    
    return plt.show()

# %%
#BarPlot function for PLotting target per target university
def BarPlot(df, target):
    fig, ax = plt.subplots()
    x_axis = [x for x in range(len(df["State"]))]
    clrs = ['b' if (x < df[target].max()) else 'r' for x in df[target]]
    ax = df[target].plot(kind = "bar", color = clrs, figsize = (20,5))
    plt.xticks(x_axis, df["School Abrev"], rotation="horizontal", fontsize = 16)
    
    # Adding tick bars on the bar Graph
    bars = ax.patches
    for bar, value in zip(bars,df[target]):
        if "Rate" in target:
            s = f"{int(round(value))}%"
        else :
            s = f"{int(round(value))}"
        ax.text(bar.get_x() + bar.get_width() / 2, y = bar.get_height()+1, s= s, color = "b",
                ha='center', va='bottom', fontsize = 16)

    plt.title(f"{target} by Target University", fontsize = 18, color = "k")
    ax.set_xlabel("Universities", fontsize = 16)
    ax.set_ylabel(f"{target}", fontsize = 16)
    ax.set_ylim(0,df[target].max()+df[target].max()*.1)
    fig.savefig(f'{target}_by_Univ.png')
    return plt.show()

# %%
#Formatting Florida SAT_ACT df and extracting target univesities
ACT_SAT = pd.DataFrame(pd.read_csv("data/SAT_ACT.csv"))

ACT_SAT = ACT_SAT.replace('-',0)
ACT_SAT.drop(ACT_SAT.head().columns[[0,1]], axis = 1, inplace = True)
for column in ACT_SAT.columns[2:-1] :
    ACT_SAT[column] = ACT_SAT[column].str.rstrip('(MT only), (CM O, (MTEN').str.replace(',', '').fillna(0).astype('int')
#Avg_ACT_SAT = ACT_SAT.groupby('State').mean().reset_index()

target_ACT_SAT = Top_Univ(ACT_SAT)
target_ACT_SAT
# Out:
#   State School Abrev                                        School Name  \
# 0    FL          FIU        Florida International University  Miami, FL
# 1    FL          FSU          Florida State University  Tallahassee, FL
# 2    FL          UCF         University of Central Florida  Orlando, FL
# 3    FL           UF             University of Florida  Gainesville, FL
# 4    FL          USF  University of South Florida-Main Campus  Tampa...
#
#   Required to Apply  SAT 25% Percentile  SAT 75% Percentile  \
# 0          Required                1090                1260
# 1          Required                1200                1350
# 2          Required                1160                1340
# 3          Required                1280                1440
# 4          Required                1170                1330
#
#    ACT 25% Percentile  ACT 75% Percentile
# 0                  65                  80
# 1                  76                  90
# 2                  71                  86
# 3                  79                  96
# 4                  72                  88

# %%
#Plotting SAT 75% percentile scores per University
BarPlot(target_ACT_SAT, "SAT 75% Percentile")

# %%
#Formatting Graduation Table
Graduation = pd.DataFrame(pd.read_csv("data/Graduation.csv"))
Graduation = Graduation.replace('-',0)
Graduation.drop(Graduation.columns[[0,1]], axis = 1, inplace = True)
for column in Graduation.columns[1:-1] :
    Graduation[column] = Graduation[column].str.strip('%').str.replace(',','').fillna(0).astype('float')
target_graduation = Top_Univ(Graduation)
target_graduation
# Out:
#   State School Abrev                                        School Name  \
# 0    FL          FIU        Florida International University  Miami, FL
# 1    FL          FSU          Florida State University  Tallahassee, FL
# 2    FL          UCF         University of Central Florida  Orlando, FL
# 3    FL           UF             University of Florida  Gainesville, FL
# 4    FL          USF  University of South Florida-Main Campus  Tampa...
#
#    Graduation Rate  Transfer-out Rate  Transfer-out Rate (BS degree)  \
# 0             57.0               19.0                            1.0
# 1             80.0                7.0                            3.0
# 2             70.0                7.0                            4.0
# 3             88.0                3.0                            2.0
# 4             71.0                6.0                            3.0
#
#    Retention Rate (Full-time)  Retention Rate (Part-time)
# 0                        88.0                        77.0
# 1                        94.0                        79.0
# 2                        90.0                        80.0
# 3                        96.0                        81.0
# 4                        90.0                        77.0

# %%
#Plotting Graduation Rate per University
BarPlot(target_graduation, "Graduation Rate")

# %%
#Formatting Tuition df
Tuition = pd.DataFrame(pd.read_csv("data/Tuition.csv"))
Tuition = Tuition.drop(0)
Tuition = Tuition.replace('-',0)
Tuition.drop(Tuition.columns[[0,1]], axis = 1, inplace = True)
for column in Tuition.columns[1:-1] :
    Tuition[column] = Tuition[column].str.strip('$, ').str.replace(',','').fillna(0).astype('float')
target_tuition = Top_Univ(Tuition)
target_tuition["Avg_tuition"] = (target_tuition["Tuition & Fees"] + target_tuition["Tuition & Fees.1"])/2
target_tuition
# Out:
#   State School Abrev                                       School Name  \
# 0    FL          FIU         Florida International UniversityMiami, FL
# 1    FL          FSU           Florida State UniversityTallahassee, FL
# 2    FL          UCF          University of Central FloridaOrlando, FL
# 3    FL           UF              University of FloridaGainesville, FL
# 4    FL          USF  University of South Florida-Main CampusTampa, FL
#
#    Tuition & Fees  Tuition & Fees.1  Cost Per Credit Hour  \
# 0          6556.0            6546.0                 206.0
# 1          5656.0           18786.0                 189.0
# 2          6368.0           22467.0                 212.0
# 3          6381.0           28659.0                 149.0
# 4          6410.0           17324.0                 211.0
#
#    Cost Per Credit Hour.1  Books & Supplies  Living Costs  Living Costs.1  \
# 0                   177.0           18954.0           0.0             0.0
# 1                   627.0            1000.0       10666.0         10666.0
# 2                   749.0            1200.0       10010.0         10010.0
# 3                   856.0            1030.0       10120.0         10120.0
# 4                   575.0            1200.0       11610.0          9820.0
#
#    Avg_tuition
# 0       6551.0
# 1      12221.0
# 2      14417.5
# 3      17520.0
# 4      11867.0

# %%
#Plotting Tuition & Fees per University
BarPlot(target_tuition, "Avg_tuition")

# %%
#Formatting Acceptance Table
Accept = pd.DataFrame(pd.read_csv("data/Acceptance.csv"))
Accept.drop(Accept.columns[[0,1]], axis = 1, inplace = True)
for column in Accept.columns[1:-1] :
    try:
        Accept[column] = [round(float(x.strip("$,%")),2) for x in Accept[column]]
    except:
        pass
target_acceptance = Top_Univ(Accept)

# %%
#Plotting Acceptance Rate per University
BarPlot(target_acceptance, "Acceptance Rate")

# %%
#Formatting Acceptance Table
Student_p = pd.DataFrame(pd.read_csv("data/Students_pop.csv"))
Student_p.drop(Student_p.columns[[0,1]], axis = 1, inplace = True)
for column in Student_p.columns[1:-1] :
    try:
        Student_p[column] = [round(float(x.strip("$,%")),2) for x in Student_p[column]]
    except:
        pass
target_studentP = Top_Univ(Student_p)

# %%
#Plotting student population per University
BarPlot(target_studentP, "Total")

# %%
# Genrating new table with all my parameters
Grad_rate = target_graduation["Graduation Rate"]
Tuition_fees = target_tuition["Avg_tuition"]
Accept_rate = target_acceptance["Acceptance Rate"]
school_size = target_studentP["Total"]
SAT_75_Percent = target_ACT_SAT["SAT 75% Percentile"]
SAT_25_Percent = target_ACT_SAT["SAT 25% Percentile"]
ACT_75_Percent = target_ACT_SAT["ACT 75% Percentile"]
ACT_25_Percent = target_ACT_SAT["ACT 25% Percentile"]

#Creating Table with target attributes
target_table = pd.DataFrame({"Grad_rate":Grad_rate,
                             "Tuition_fees":Tuition_fees,
                             "Accept_rate":Accept_rate,
                             "school_size":school_size,
                             "SAT_75-Percent":SAT_75_Percent,
                             "SAT_25-Percent":SAT_25_Percent,
                            "ACT_75_Percent":ACT_75_Percent,
                            "ACT_25_Percent":ACT_25_Percent})

#Plotting correlation heat map
fig, ax = plt.subplots(figsize=(10,10))

corr = target_table.corr()
ax = sns.heatmap(corr,annot=True, square=True, vmin=-1, vmax=1, center=0, linewidths=.5, cmap='PuOr')
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, horizontalalignment='right')
ax.set_ylim(8.0, 0)
plt.title("Correlation map", fontsize = 19, color ="b")
fig.savefig('heatmap.png')
plt.show()

# %%
corr.style.highlight_min(axis=0)
#corr.style.highlight_max(axis=0)
# Out:
# <style  type="text/css" >
#     #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col0 {
#             background-color:  yellow;
#         }    #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col1 {
#             background-color:  yellow;
#         }    #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col4 {
#             background-color:  yellow;
#         }    #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col5 {
#             background-color:  yellow;
#         }    #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col6 {
#             background-color:  yellow;
#         }    #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col7 {
#             background-color:  yellow;
#         }    #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row7_col2 {
#             background-color:  yellow;
#         }    #T_2af48058_ec3e_11e9_af44_f8633f7d4c35row7_col3 {
#             background-color:  yellow;
#         }</style><table id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Grad_rate</th>        <th class="col_heading level0 col1" >Tuition_fees</th>        <th class="col_heading level0 col2" >Accept_rate</th>        <th class="col_heading level0 col3" >school_size</th>        <th class="col_heading level0 col4" >SAT_75-Percent</th>        <th class="col_heading level0 col5" >SAT_25-Percent</th>        <th class="col_heading level0 col6" >ACT_75_Percent</th>        <th class="col_heading level0 col7" >ACT_25_Percent</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35level0_row0" class="row_heading level0 row0" >Grad_rate</th>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col1" class="data row0 col1" >0.874979</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col2" class="data row0 col2" >-0.88895</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col3" class="data row0 col3" >-0.352404</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col4" class="data row0 col4" >0.957087</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col5" class="data row0 col5" >0.983989</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col6" class="data row0 col6" >0.986383</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row0_col7" class="data row0 col7" >0.99806</td>
#             </tr>
#             <tr>
#                         <th id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35level0_row1" class="row_heading level0 row1" >Tuition_fees</th>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col0" class="data row1 col0" >0.874979</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col2" class="data row1 col2" >-0.814607</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col3" class="data row1 col3" >0.0652497</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col4" class="data row1 col4" >0.948699</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col5" class="data row1 col5" >0.90144</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col6" class="data row1 col6" >0.88834</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row1_col7" class="data row1 col7" >0.860918</td>
#             </tr>
#             <tr>
#                         <th id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35level0_row2" class="row_heading level0 row2" >Accept_rate</th>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col0" class="data row2 col0" >-0.88895</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col1" class="data row2 col1" >-0.814607</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col2" class="data row2 col2" >1</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col3" class="data row2 col3" >0.390248</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col4" class="data row2 col4" >-0.791325</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col5" class="data row2 col5" >-0.819861</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col6" class="data row2 col6" >-0.850394</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row2_col7" class="data row2 col7" >-0.908264</td>
#             </tr>
#             <tr>
#                         <th id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35level0_row3" class="row_heading level0 row3" >school_size</th>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col0" class="data row3 col0" >-0.352404</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col1" class="data row3 col1" >0.0652497</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col2" class="data row3 col2" >0.390248</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col4" class="data row3 col4" >-0.129002</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col5" class="data row3 col5" >-0.276493</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col6" class="data row3 col6" >-0.34845</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row3_col7" class="data row3 col7" >-0.397702</td>
#             </tr>
#             <tr>
#                         <th id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35level0_row4" class="row_heading level0 row4" >SAT_75-Percent</th>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col0" class="data row4 col0" >0.957087</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col1" class="data row4 col1" >0.948699</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col2" class="data row4 col2" >-0.791325</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col3" class="data row4 col3" >-0.129002</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col4" class="data row4 col4" >1</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col5" class="data row4 col5" >0.987771</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col6" class="data row4 col6" >0.974044</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row4_col7" class="data row4 col7" >0.941863</td>
#             </tr>
#             <tr>
#                         <th id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35level0_row5" class="row_heading level0 row5" >SAT_25-Percent</th>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row5_col0" class="data row5 col0" >0.983989</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row5_col1" class="data row5 col1" >0.90144</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row5_col2" class="data row5 col2" >-0.819861</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row5_col3" class="data row5 col3" >-0.276493</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row5_col4" class="data row5 col4" >0.987771</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c35row5_col5" class="data row5 col5" >1</td>
#                         <td id="T_2af48058_ec3e_11e9_af44_f8633f7d4c

# %%
Plot(Grad_rate, Tuition_fees)

# %%
Plot(Grad_rate, Accept_rate)

# %%
Plot(Grad_rate, SAT_75_Percent)

# %%
Plot(Grad_rate, school_size)

# %%
Plot(Grad_rate, SAT_25_Percent)

# %%
Plot(Grad_rate, ACT_25_Percent)

# %%
Plot(Grad_rate, ACT_75_Percent)
